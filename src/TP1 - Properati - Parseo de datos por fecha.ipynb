# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
import glob
# %matplotlib inline

# %% [markdown]
# ## Asi quedaria en primera instancia...
# #### hay que borrar los print de debug, nota: la fecha 2013-07 tambien la toma, pero esto es sencillo para despues filtrarlo y sacarlo

# %%
ruta ='' # use your path
allFiles = glob.glob(ruta + "*.csv")
datos = pd.DataFrame()

for archivos in allFiles:
    # Leo el archivo con el nombre original
    df = pd.read_csv(archivos)
    properati,ar,anio,mes,dia,propiedad,ventas = archivos.split('-')
    
    if mes != "01":
        if ( anio == "2017" and mes == "08"):
            fechaABuscar = anio + "-" + mes
            print "2017-08"
            print fechaABuscar
            df = df[df['created_on'].str.contains('2017-08') | df['created_on'].str.contains('2017-07')]
        else:
            fechaABuscar = anio + "-" + str(int(mes) - 1).zfill(2)
            print fechaABuscar  
            df = df[df['created_on'].str.contains(fechaABuscar)]            
    else:
        fechaABuscar = str(int(anio) -1) + "-" + "12"
        print fechaABuscar
        df = df[df['created_on'].str.contains(fechaABuscar)]    
    datos = pd.concat([datos,df])
# Out:
# 2013-07
# 2013-08
# 2013-09
# 2013-10
# 2013-11
# 2013-12
# 2014-01
# 2014-02
# 2014-03
# 2014-04
# 2014-05
# 2014-06
# 2014-07
# 2014-08
# 2014-09
# 2014-10
# 2014-11
# 2014-12
# 2015-01
# 2015-02
# 2015-03
# 2015-04
# 2015-05
# 2015-06
# 2015-07
# 2015-08
# 2015-09
# D:\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2723: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 2015-10
# D:\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2723: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 2015-11
# 2015-12
# 2016-01
# 2016-02
# 2016-03
# 2016-04
# 2016-05
# 2016-06
# 2016-07
# 2016-08
# 2016-09
# 2016-10
# 2016-11
# 2016-12
# 2017-01
# 2017-02
# 2017-03
# 2017-04
# 2017-05
# 2017-06
# 2017-08
# 2017-08

# %%
datos
# Out:
#        country_name  created_on currency  \
# 36436           NaN  2013-07-01      USD
# 36437           NaN  2013-07-01      USD
# 36438           NaN  2013-07-01      USD
# 36439           NaN  2013-07-01      USD
# 36440           NaN  2013-07-01      USD
# 36441           NaN  2013-07-01      USD
# 36442           NaN  2013-07-01      USD
# 36443           NaN  2013-07-01      USD
# 36444           NaN  2013-07-01      USD
# 36445           NaN  2013-07-01      USD
# 36446           NaN  2013-07-01      ARS
# 36447           NaN  2013-07-01      NaN
# 36448           NaN  2013-07-01      USD
# 36449           NaN  2013-07-01      USD
# 36450           NaN  2013-07-01      USD
# 36451           NaN  2013-07-01      USD
# 36452           NaN  2013-07-01      USD
# 36453           NaN  2013-07-01      USD
# 36454           NaN  2013-07-01      USD
# 36455           NaN  2013-07-01      USD
# 36456           NaN  2013-07-01      USD
# 36457           NaN  2013-07-01      USD
# ...
