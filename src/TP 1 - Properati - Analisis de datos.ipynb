# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
import glob
# %matplotlib inline

# %%
properati = pd.read_csv('data/properati_full_data.csv')
# Out:
# D:\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2723: DtypeWarning: Columns (0,3,4,5,8,24,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
properati.shape
# Out:
# (2629155, 29)

# %%
properati.dtypes
# Out:
# country_name                   object
# created_on                     object
# currency                       object
# description                    object
# expenses                       object
# extra                          object
# floor                         float64
# geonames_id                   float64
# id                             object
# image_thumbnail                object
# lat                           float64
# lat-lon                        object
# lon                           float64
# operation                      object
# place_name                     object
# place_with_parent_names        object
# price                         float64
# price_aprox_local_currency    float64
# price_aprox_usd               float64
# price_per_m2                  float64
# price_usd_per_m2              float64
# properati_url                  object
# property_type                  object
# rooms                         float64
# state_name                     object
# ...

# %%
properati[[0]]
# Out:
#         country_name
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9                NaN
# 10               NaN
# 11               NaN
# 12               NaN
# 13               NaN
# 14               NaN
# 15               NaN
# 16               NaN
# 17               NaN
# 18               NaN
# 19               NaN
# 20               NaN
# 21               NaN
# 22               NaN
# 23               NaN
# 24               NaN
# 25               NaN
# 26               NaN
# 27               NaN
# 28               NaN
# 29               NaN
# ...              ...
# 2629125    Argentina
# 2629126    Argentina
# 2629127    Argentina
# 2629128    Argentina
# 2629129    Argentina
# 2629130    Argentina
# 2629131    Argentina
# 2629132    Argentina
# 2629133    Argentina
# 2629134    Argentina
# 2629135    Argentina
# ...

# %%
properati[[11]]
# Out:
#                                lat-lon
# 0                                  NaN
# 1                -34.561208,-58.464514
# 2                 -34.54673,-58.550579
# 3                -34.543776,-58.559615
# 4                                  NaN
# 5                -34.568371,-58.598724
# 6                -34.553995,-58.556645
# 7                -34.561351,-58.516614
# 8                -34.553385,-58.551283
# 9                -34.561914,-58.593487
# 10                                 NaN
# 11               -34.597915,-58.417149
# 12               -34.597915,-58.417149
# 13                                 NaN
# 14                                 NaN
# 15               -34.451013,-58.626786
# 16                                 NaN
# 17               -34.626877,-58.478199
# 18                -34.560486,-58.55855
# 19               -34.633633,-58.484419
# 20                -34.60882,-58.430529
# 21               -34.651912,-58.519874
# 22                                 NaN
# ...

# %%
properati.head(4)
# Out:
#   country_name  created_on currency description   expenses extra  floor  \
# 0          NaN  2012-08-08      NaN         NaN        NaN   NaN    NaN
# 1          NaN  2012-08-08      NaN         NaN  850 aprox   NaN   10.0
# 2          NaN  2012-08-08      NaN         NaN        NaN   NaN   11.0
# 3          NaN  2012-08-08      NaN         NaN        NaN   NaN    NaN
#
#    geonames_id   id                                    image_thumbnail  ...    \
# 0    3429308.0  NaN  http://cf-thumbs.properati.com.ar/ERAJ8jc7-_PF...  ...
# 1    3436077.0  NaN  http://cf-thumbs.properati.com.ar/6edbfyb8tqyL...  ...
# 2    3427467.0  NaN  http://cf-thumbs.properati.com.ar/xo7gQPyQ4luR...  ...
# 3    3427467.0  NaN  http://cf-thumbs.properati.com.ar/7p5FCLYnTd-D...  ...
#
#    price_per_m2 price_usd_per_m2  \
# 0           NaN              NaN
# 1           NaN              NaN
# 2           NaN              NaN
# 3           NaN              NaN
#
# ...

# %%
properati.expenses.unique()
# Out:
# array([nan, '850 aprox', '$1000', ..., 5799.0, 865906.0, 4385.0], dtype=object)

# %%
properati['created_on'] = pd.to_datetime(properati['created_on'])

# %%
properati[properati.lat.isnull()]
# Out:
#         country_name created_on currency  \
# 0                NaN 2012-08-08      NaN
# 4                NaN 2012-08-08      USD
# 10               NaN 2012-08-08      NaN
# 13               NaN 2012-08-08      USD
# 14               NaN 2012-08-08      USD
# 16               NaN 2012-08-08      USD
# 22               NaN 2012-08-18      USD
# 25               NaN 2012-09-12      USD
# 26               NaN 2012-09-19      USD
# 34               NaN 2012-09-19      USD
# 35               NaN 2012-09-19      USD
# 36               NaN 2012-09-19      USD
# 37               NaN 2012-09-19      USD
# 57               NaN 2012-10-05      USD
# 61               NaN 2012-10-06      USD
# 63               NaN 2012-10-06      NaN
# 68               NaN 2012-10-10      USD
# 70               NaN 2012-10-10      USD
# 71               NaN 2012-10-10      USD
# 92               NaN 2012-10-10      USD
# 115              NaN 2012-10-10      USD
# 134              NaN 2012-10-10      USD
# ...

# %%
properati.id.unique()
# Out:
# array([nan, '6c0506bbb9df96cbf7b5b2f64fc594ddfe7b1235',
#        'd758dcbe4f031408b5aa2890172359a410f43b47', ...,
#        'e935e6dca58a5b2fec2101f8c7ac1494722119a6',
#        'd236e3424ac94ab9fcd5d2c22aed59eeed695adc',
#        '9439664d30d10181efbae84ed01e6d991087deed'], dtype=object)

# %%
properati.id.value_counts()
# Out:
# 3c39f4d78fe77ef8a48eafcf21bc71ea909bda76    6
# 933d4ca273da0d793479d624f83ba8be05c99ee0    6
# 372b3521afc2e4709fe928646bbb5a50d898edc8    6
# 40f9a4eb373b745898083fb9f2b89edd686c8e0f    6
# c116aea30849a28c76d84b9311415666e5d9dcf9    6
# 7e2901885f7b92447c971b60c7d7a6b74e16e6da    6
# acc80a31c0a4fee1fde632e1dacb39ccf084e175    6
# 48f1def8e1238cf513cccb2b2b57706bf764a32d    6
# d29541c8a4da66b70c4c6768a351d9444544b4b5    6
# 467466a822eb6ba8e6aa3d239ba3ed6b7d91a0f0    6
# 7cb040d355da5f68c1b157f82289d8072b16c2a1    6
# 505d4d9baa77731070a2e7b3a812ed2dd239701d    6
# 775d8533b35e59ef594df6b653237a9601617372    6
# 330631c276a6ac856e579cfe1626a02d505643b7    6
# e5320ad2eba49dff1c081477147b79e5369bb119    6
# 8273bfa11a303695b5cab80c7d78ee441121a340    6
# 8c3f7cbeae3eeadf68ae463bca7d9b407ef060dc    6
# 4a17ce78e8eedd1f036d83885d19028c6a28f36c    6
# 318974f73d89a0d4293ca193e284bc3c09acf1b1    6
# 10189ced50d865d471e5eb01d3876562489a5b72    6
# ...

# %%
properati.id.value_counts(dropna=False)
# Out:
# NaN                                         1999835
# 4a17ce78e8eedd1f036d83885d19028c6a28f36c          6
# 330631c276a6ac856e579cfe1626a02d505643b7          6
# c116aea30849a28c76d84b9311415666e5d9dcf9          6
# 318974f73d89a0d4293ca193e284bc3c09acf1b1          6
# cb6661a7ae450080a5416e2089211e17170454ab          6
# 505d4d9baa77731070a2e7b3a812ed2dd239701d          6
# 7e2901885f7b92447c971b60c7d7a6b74e16e6da          6
# 48f1def8e1238cf513cccb2b2b57706bf764a32d          6
# 40f9a4eb373b745898083fb9f2b89edd686c8e0f          6
# 3c39f4d78fe77ef8a48eafcf21bc71ea909bda76          6
# 2eb2967d1bda5b602273c63a91753e766b10357d          6
# 7cb040d355da5f68c1b157f82289d8072b16c2a1          6
# 3f32d5e3efdb3363dd424453ce28a6fa33f699fb          6
# 372b3521afc2e4709fe928646bbb5a50d898edc8          6
# 00dd23235edecf5c74d19fa9be4ab63c48aacad5          6
# 8273bfa11a303695b5cab80c7d78ee441121a340          6
# 8c3f7cbeae3eeadf68ae463bca7d9b407ef060dc          6
# ...

# %%
properati.state_name.value_counts(dropna=False)
# Out:
# NaN                             1999835
# Capital Federal                  160659
# Bs.As. G.B.A. Zona Norte         140709
# Bs.As. G.B.A. Zona Oeste          74182
# Buenos Aires Costa Atlántica      70149
# Bs.As. G.B.A. Zona Sur            50210
# Córdoba                           42212
# Santa Fe                          33898
# Buenos Aires Interior             16563
# Maldonado                         14630
# Mendoza                            3242
# Neuquén                            2977
# Misiones                           2954
# Río Negro                          2920
# Montevideo                         2915
# Entre Ríos                         2395
# Tucumán                            1315
# San Luis                           1310
# Salta                              1268
# La Pampa                            861
# Corrientes                          752
# Chubut                              672
# Catamarca                           494
# ...

# %%
properati[properati.state_name.isnull()][['country_name','place_name','state_name']]
# Out:
#         country_name           place_name state_name
# 0                NaN  San Andrés de Giles        NaN
# 1                NaN             Belgrano        NaN
# 2                NaN      Villa Ballester        NaN
# 3                NaN      Villa Ballester        NaN
# 4                NaN      Villa Ballester        NaN
# 5                NaN         Loma Hermosa        NaN
# 6                NaN      Villa Ballester        NaN
# 7                NaN           San Martín        NaN
# 8                NaN      Villa Ballester        NaN
# 9                NaN      Villa Ballester        NaN
# 10               NaN          Berazategui        NaN
# 11               NaN              Palermo        NaN
# 12               NaN              Palermo        NaN
# 13               NaN                Tigre        NaN
# 14               NaN                Pilar        NaN
# 15               NaN                Tigre        NaN
# 16               NaN          Las Cañitas        NaN
# ...

# %%
properati[properati.state_name == "Buenos Aires Interior"][['country_name','place_name','state_name']]
# Out:
#         country_name             place_name             state_name
# 1999923    Argentina           Bahía Blanca  Buenos Aires Interior
# 2000064    Argentina               Ensenada  Buenos Aires Interior
# 2000065    Argentina           Bahía Blanca  Buenos Aires Interior
# 2000301    Argentina           Bahía Blanca  Buenos Aires Interior
# 2000347    Argentina                Lobería  Buenos Aires Interior
# 2000370    Argentina           Bahía Blanca  Buenos Aires Interior
# 2000392    Argentina         Coronel Suárez  Buenos Aires Interior
# 2000411    Argentina                  Luján  Buenos Aires Interior
# 2000422    Argentina               Brandsen  Buenos Aires Interior
# 2000466    Argentina           Bahía Blanca  Buenos Aires Interior
# 2000492    Argentina                 Zárate  Buenos Aires Interior
# 2000493    Argentina                 Zárate  Buenos Aires Interior
# 2000494    Argentina                 Zárate  Buenos Aires Interior
# ...

# %%
properati[properati.state_name == "Buenos Aires Costa Atlántica"][['country_name','place_name','state_name']]
# Out:
#         country_name     place_name                    state_name
# 1999835    Argentina  Mar del Plata  Buenos Aires Costa Atlántica
# 1999852    Argentina  Mar del Plata  Buenos Aires Costa Atlántica
# 1999853    Argentina  Mar del Plata  Buenos Aires Costa Atlántica
# 1999854    Argentina  Mar del Plata  Buenos Aires Costa Atlántica
# 1999855    Argentina  Mar del Plata  Buenos Aires Costa Atlántica
# 1999856    Argentina  Mar del Plata  Buenos Aires Costa Atlántica
# 1999857    Argentina  Mar del Plata  Buenos Aires Costa Atlántica
# 1999876    Argentina  Mar del Plata  Buenos Aires Costa Atlántica
# 1999887    Argentina  Mar del Plata  Buenos Aires Costa Atlántica
# 1999888    Argentina  Mar del Plata  Buenos Aires Costa Atlántica
# 1999889    Argentina  Mar del Plata  Buenos Aires Costa Atlántica
# 1999890    Argentina  Mar del Plata  Buenos Aires Costa Atlántica
# 1999891    Argentina  Mar del Plata  Buenos Aires Costa Atlántica
# ...

# %%
properati[['country_name','place_name','state_name']]
# Out:
#         country_name               place_name                state_name
# 0                NaN      San Andrés de Giles                       NaN
# 1                NaN                 Belgrano                       NaN
# 2                NaN          Villa Ballester                       NaN
# 3                NaN          Villa Ballester                       NaN
# 4                NaN          Villa Ballester                       NaN
# 5                NaN             Loma Hermosa                       NaN
# 6                NaN          Villa Ballester                       NaN
# 7                NaN               San Martín                       NaN
# 8                NaN          Villa Ballester                       NaN
# 9                NaN          Villa Ballester                       NaN
# 10               NaN              Berazategui                       NaN
# 11               NaN                  Palermo                       NaN
# ...

# %%
properati.created_on.isnull().any()
# Out:
# False

# %%
properati.country_name.value_counts(dropna=False)
# Out:
# NaN               1999835
# Argentina          610856
# Uruguay             17833
# Estados Unidos        578
# Brasil                 53
# Name: country_name, dtype: int64

# %%
properati.lat.isnull().sum()
# Out:
# 651377

# %%
properati.lat.value_counts(dropna=False)
# Out:
# NaN           651377
# -34.000000      8567
# -34.603771      7510
# -34.577168      5202
# -29.537050      4165
# -34.425087      3914
# -34.447361      3428
# -34.451013      3105
# -34.455906      3085
# -31.398930      3015
# -34.603723      2493
# -34.603723      2294
# -34.451013      2262
# -34.607633      2050
# -34.588889      2004
# -37.979858      1998
# -34.663673      1950
# -34.603684      1926
# -38.416097      1920
# -34.324581      1780
# -34.936879      1534
# -34.615974      1490
# -31.420083      1478
# -34.453061      1472
# -34.470829      1359
# -34.633333      1314
# -34.400140      1311
# -34.934430      1283
# -34.562500      1277
# -34.446523      1272
#                ...
# -34.626596         1
# -34.553351         1
# -31.046527         1
# -37.271094         1
# -34.937962         1
# -34.543359         1
# -31.426401         1
# -34.482044         1
# -34.932025         1
#  25.669790         1
# -34.625613         1
# -34.639760         1
# ...

# %%
properati.place_name.isnull().sum()
# Out:
# 143

# %%
properati.geonames_id.isnull().sum()
# Out:
# 393586

# %%
properati.place_name.value_counts(dropna=False)
# Out:
# Mar del Plata                         233110
# Capital Federal                        87511
# Córdoba                                71517
# Tigre                                  69852
# Rosario                                68170
# Pilar                                  67588
# Nordelta                               61812
# Belgrano                               60378
# Punta del Este                         57280
# Ramos Mejía                            55799
# Palermo                                52837
# La Plata                               39120
# Caballito                              38267
# Olivos                                 35780
# Morón                                  34400
# San Isidro                             32915
# Ituzaingó                              31889
# Pinamar                                30064
# Santa Fe                               29464
# Villa Urquiza                          29120
# Benavidez                              29039
# ...

# %%
properati[properati.id == "3c39f4d78fe77ef8a48eafcf21bc71ea909bda76"]
# Out:
#         country_name created_on currency  \
# 2045123    Argentina 2016-03-21      USD
# 2116959    Argentina 2016-10-09      USD
# 2214758    Argentina 2017-05-26      USD
# 2376773    Argentina 2017-05-26      USD
# 2433377    Argentina 2017-05-26      USD
# 2488539    Argentina 2017-05-26      USD
#
#                                                description expenses extra  \
# 2045123  Corredor Responsable: Florencia Balague - C.M....      NaN   NaN
# 2116959  Corredor Responsable: FLORENCIA BALAGUE - CMCP...      NaN   NaN
# 2214758  Corredor Responsable: FLORENCIA BALAGUE - CMCP...      NaN   NaN
# 2376773  Corredor Responsable: FLORENCIA BALAGUE - CMCP...      NaN   NaN
# 2433377  Corredor Responsable: FLORENCIA BALAGUE - CMCP...      NaN   NaN
# 2488539  Corredor Responsable: FLORENCIA BALAGUE - CMCP...      NaN   NaN
#
#          floor  geonames_id                                        id  \
# 2045123    NaN    3427463.0  3c39f4d78fe77ef8a48eafcf21bc71ea909bda76
# ...

# %% [markdown]
# # Filtrado de lugares de la Argentina, capital y Gran Buenos Aires
# -   country_name
# -   place_name
# -   state_name

# %% [markdown]
# # Filtrado de paises, se tienen en cuenta los nulos y Argentina

# %%
properati = properati[properati.country_name.isnull() | properati.country_name.isin(['Argentina'])]
properati
# Out:
#         country_name created_on currency  \
# 0                NaN 2012-08-08      NaN
# 1                NaN 2012-08-08      NaN
# 2                NaN 2012-08-08      NaN
# 3                NaN 2012-08-08      NaN
# 4                NaN 2012-08-08      USD
# 5                NaN 2012-08-08      NaN
# 6                NaN 2012-08-08      NaN
# 7                NaN 2012-08-08      USD
# 8                NaN 2012-08-08      NaN
# 9                NaN 2012-08-08      NaN
# 10               NaN 2012-08-08      NaN
# 11               NaN 2012-08-08      USD
# 12               NaN 2012-08-08      USD
# 13               NaN 2012-08-08      USD
# 14               NaN 2012-08-08      USD
# 15               NaN 2012-08-08      USD
# 16               NaN 2012-08-08      USD
# 17               NaN 2012-08-09      USD
# 18               NaN 2012-08-15      NaN
# 19               NaN 2012-08-15      USD
# 20               NaN 2012-08-15      USD
# 21               NaN 2012-08-17      USD
# ...

# %% [markdown]
# # Filtrado de state_name
# - Capital Federal
# - Bs.As. G.B.A. Zona Norte
# - Bs.As. G.B.A. Zona Oeste
# - Buenos Aires Costa Atlántica
# - Bs.As. G.B.A. Zona Sur
# - Buenos Aires Interior

# %%
properati = properati[properati.state_name.isnull() | properati.state_name.isin(['Capital Federal','Bs.As. G.B.A. Zona Norte',\
                                                    'Bs.As. G.B.A. Zona Oeste','Buenos Aires Costa Atlántica',\
                                                    'Bs.As. G.B.A. Zona Sur','Buenos Aires Interior'])]
properati
# Out:
#         country_name created_on currency  \
# 0                NaN 2012-08-08      NaN
# 1                NaN 2012-08-08      NaN
# 2                NaN 2012-08-08      NaN
# 3                NaN 2012-08-08      NaN
# 4                NaN 2012-08-08      USD
# 5                NaN 2012-08-08      NaN
# 6                NaN 2012-08-08      NaN
# 7                NaN 2012-08-08      USD
# 8                NaN 2012-08-08      NaN
# 9                NaN 2012-08-08      NaN
# 10               NaN 2012-08-08      NaN
# 11               NaN 2012-08-08      USD
# 12               NaN 2012-08-08      USD
# 13               NaN 2012-08-08      USD
# 14               NaN 2012-08-08      USD
# 15               NaN 2012-08-08      USD
# 16               NaN 2012-08-08      USD
# 17               NaN 2012-08-09      USD
# 18               NaN 2012-08-15      NaN
# 19               NaN 2012-08-15      USD
# 20               NaN 2012-08-15      USD
# 21               NaN 2012-08-17      USD
# ...

# %% [markdown]
# # Filtrado de place name , capital y gran bs as

# %% [markdown]
# ### Creo las listas nombres de los lugares de cada zona, para despues poder filtrar a los que tienen NaN

# %%
listaCapFed = properati.place_name[properati.state_name == "Capital Federal"].unique().tolist()
listaCapFed
# Out:
# ['Palermo',
#  'Villa del Parque',
#  'Barracas',
#  'Congreso',
#  'Parque Patricios',
#  'Belgrano',
#  'Capital Federal',
#  'Flores',
#  'Villa Crespo',
#  'Parque Avellaneda',
#  'Villa Urquiza',
#  'San Cristobal',
#  'Boedo',
#  'Almagro',
#  'Saavedra',
#  'Puerto Madero',
#  'Barrio Norte',
#  'Villa Devoto',
#  'Coghlan',
#  'Balvanera',
#  'Caballito',
#  'Villa Real',
#  'Retiro',
#  'Boca',
#  'Abasto',
#  'Villa Lugano',
#  'Monte Castro',
#  'Monserrat',
#  'Mataderos',
#  'Once',
#  'Recoleta',
#  'Villa Santa Rita',
#  'Palermo Hollywood',
#  'Floresta',
#  'Nu\xc3\xb1ez',
#  'Paternal',
#  'Villa Luro',
#  'Liniers',
#  'Chacarita',
#  'Colegiales',
#  'Villa Pueyrred\xc3\xb3n',
#  'Las Ca\xc3\xb1itas',
#  'San Nicol\xc3\xa1s',
#  'Palermo Chico',
#  'Parque Chacabuco',
#  'Palermo Soho',
#  'Centro / Microcentro',
#  'Constituci\xc3\xb3n',
#  'Pompeya',
#  'San Telmo',
#  'Catalinas',
#  'Villa General Mitre',
#  'Agronom\xc3\xada',
#  'Versalles',
# ...

# %%
listaZonaNorte = properati.place_name[properati.state_name == "Bs.As. G.B.A. Zona Norte"].unique().tolist()
listaZonaNorte
# Out:
# ['San Mart\xc3\xadn',
#  'San Miguel',
#  'Pilar',
#  'Nordelta',
#  'General San Mart\xc3\xadn',
#  'La Arboleda de Maschwitz',
#  'Tigre',
#  'San Isidro',
#  'Mart\xc3\xadnez',
#  'Don Torcuato',
#  'Villa Adelina',
#  'Villa de Mayo',
#  'Benavidez',
#  'Victoria',
#  'Estancias del Pilar',
#  'Villa Ballester',
#  'Olivos',
#  'Vicente L\xc3\xb3pez',
#  'Florida',
#  'Escobar',
#  'General Pacheco',
#  'Beccar',
#  'Acassuso',
#  'Barrio San Mat\xc3\xadas',
#  'La Lucila',
#  'Del Viso',
#  'Bel\xc3\xa9n de Escobar',
#  'Mu\xc3\xb1iz',
#  'Barrio Los Alisos',
#  'Tortuguitas',
#  'Malvinas Argentinas',
#  'Matheu',
#  'El Cazador',
#  'Maschwitz',
#  'San Fernando',
#  'Munro',
#  'Delta',
#  ' Country Maschwitz Club',
#  'Boulogne Sur Mer',
#  'Rinc\xc3\xb3n de Milberg',
#  'Los Polvorines',
#  'Bs.As. G.B.A. Zona Norte',
#  'Carapachay',
#  'Dique Luj\xc3\xa1n',
#  'El Talar',
#  'Loma Verde',
#  'Bella Vista',
#  'Los Angeles Village',
#  'La Candelaria de Maschwitz',
# ...

# %%
listaZonaOeste = properati.place_name[properati.state_name == "Bs.As. G.B.A. Zona Oeste"].unique().tolist()
listaZonaOeste
# Out:
# ['Villa Sarmiento',
#  'Ituzaing\xc3\xb3',
#  'Hurlingham',
#  'La Tablada',
#  'Mart\xc3\xadn Coronado',
#  'Mor\xc3\xb3n',
#  'Merlo',
#  'Ramos Mej\xc3\xada',
#  'Haedo',
#  'San Antonio De Padua',
#  'Caseros',
#  'Moreno',
#  'Castelar',
#  'Villa Luzuriaga',
#  'La Matanza',
#  'El Palomar',
#  'Villa Bosch',
#  'Tres de Febrero',
#  'Ciudadela',
#  'San Diego Country Club',
#  'Lomas del Mirador',
#  'St. Patrick Country',
#  'Campos de \xc3\x81lvarez',
#  'Libertad',
#  'Parque Leloir',
#  'Villa Udaondo',
#  'Gregorio de Laferrere',
#  'Marcos Paz',
#  'Isidro Casanova',
#  'San Justo',
#  'Virrey del Pino',
#  'Villa Madero',
#  'Gonz\xc3\xa1lez Cat\xc3\xa1n',
#  'Ciudad Evita',
#  'Villa Celina',
#  'Tapiales',
#  'Rafael Castillo',
#  'Pontevedra',
#  'Ciudad Jard\xc3\xadn Lomas del Palomar',
#  'Villa Tesei',
#  'La Reja',
#  'Santos Lugares',
#  'Bs.As. G.B.A. Zona Oeste',
#  'El Casco de Leloir',
#  'Paso del Rey',
#  'Pablo Podest\xc3\xa1',
#  'Loma Hermosa',
# ...

# %%
listaCostaAtl = properati.place_name[properati.state_name == "Buenos Aires Costa Atlántica"].unique().tolist()
listaCostaAtl
# Out:
# ['Mar del Plata',
#  'Pinamar',
#  'Villa Gesell',
#  'Costa del Este',
#  'Chauv\xc3\xadn',
#  'San Bernardo',
#  'Centro',
#  'Los Troncos',
#  'San Clemente del Tuy\xc3\xba',
#  'Rumenco',
#  'Caril\xc3\xb3',
#  'Monte Hermoso',
#  'Santa Teresita',
#  'Costa Esmeralda',
#  'Mar del Tuy\xc3\xba',
#  'La Lucila del Mar',
#  'Chapadmalal',
#  'Las Toninas',
#  'Mar de Aj\xc3\xb3',
#  'Don Bosco',
#  'La Perla',
#  'Necochea',
#  'Mar de Cobo',
#  'Santa Clara del Mar',
#  'Valeria del Mar',
#  'Nueva Atlantis',
#  'Mar del Sur',
#  'Atl\xc3\xa1ntida',
#  'Faro Norte',
#  'Miramar',
#  'Punta Mogotes',
#  'Mar de las Pampas',
#  'Buenos Aires Costa Atl\xc3\xa1ntica',
#  'Playa Chica',
#  'Torre\xc3\xb3n',
#  'Constituci\xc3\xb3n',
#  'Bosque Peralta Ramos',
#  'Ostende',
#  'Claromec\xc3\xb3',
#  'Las Avenidas',
#  'Macrocentro',
#  'Stella Maris',
#  'Plaza Col\xc3\xb3n',
#  'Mar Chiquita',
#  'Caisamar',
#  'Barrio San Jose',
#  'Mundialista',
#  'Villa Primera',
# ...

# %%
listaZonaSur = properati.place_name[properati.state_name == "Bs.As. G.B.A. Zona Sur"].unique().tolist()
listaZonaSur
# Out:
# ['Lan\xc3\xbas',
#  'Temperley',
#  'Lomas de Zamora',
#  'Banfield',
#  'La Plata',
#  'Burzaco',
#  'Ezeiza',
#  'Monte Grande',
#  'Canning',
#  'Ca\xc3\xb1uelas',
#  'Valent\xc3\xadn Alsina',
#  'Remedios de Escalada',
#  'Esteban Echeverr\xc3\xada',
#  'City Bell',
#  'Turdera',
#  'Berazategui',
#  'Avellaneda',
#  'Adrogu\xc3\xa9',
#  'Villa Dominico',
#  'Country Golf El Sosiego',
#  'Manuel B Gonnet',
#  'Lan\xc3\xbas Oeste',
#  'Quilmes',
#  'Villa Elisa',
#  'Longchamps',
#  'Glew',
#  'Presidente Per\xc3\xb3n',
#  'Sarandi',
#  'Almirante Brown',
#  'Claypole',
#  'Jose Marmol',
#  'Wilde',
#  'Rafael Calzada',
#  'Bs.As. G.B.A. Zona Sur',
#  'Luis Guill\xc3\xb3n',
#  'Barrio Privado Santo Domingo',
#  'Abril Club de Campo',
#  'Ministro Rivadavia',
#  'Ranelagh',
#  'Carlos Spegazzini',
#  'Los Hornos',
#  'Tolosa',
#  'Trist\xc3\xa1n Su\xc3\xa1rez',
#  'Ezpeleta',
#  'Don Bosco',
#  'Llavallol',
#  'Guernica',
#  'Lan\xc3\xbas Este',
# ...

# %%
listaBsAsInterior = properati.place_name[properati.state_name == "Buenos Aires Interior"].unique().tolist()
listaBsAsInterior
# Out:
# ['Bah\xc3\xada Blanca',
#  'Ensenada',
#  'Lober\xc3\xada',
#  'Coronel Su\xc3\xa1rez',
#  'Luj\xc3\xa1n',
#  'Brandsen',
#  'Z\xc3\xa1rate',
#  'San Andr\xc3\xa9s de Giles',
#  'Chivilcoy',
#  'Lobos',
#  'Sierra de los Padres',
#  'Balcarce',
#  'Cardales Country Club',
#  'Baradero',
#  'Campana',
#  'Punta Lara',
#  'Tres Arroyos',
#  'Carmen de Patagones',
#  'General Pueyrred\xc3\xb3n',
#  'General Madariaga',
#  'Lobos: cabecera del partido',
#  'Roosevelt',
#  'Buenos Aires Interior',
#  'General Las Heras',
#  'San Cayetano',
#  'Villanueva',
#  'Antonio Carboni',
#  'Empalme Lobos',
#  'Rocha',
#  'Berisso',
#  'Capit\xc3\xa1n Sarmiento',
#  'San Antonio de Areco',
#  'Arrecifes',
#  'Coronel Brandsen',
#  'Azul',
#  'Trenque Lauquen',
#  'Dolores',
#  'San Jos\xc3\xa9',
#  'Villa Arcadia',
#  'Santa Mar\xc3\xada',
#  'Tandil',
#  'Adolfo Alsina',
#  'Comandante Nicanor Otamendi',
#  'Barrio Santa Irene - Comarcas de Luj\xc3\xa1n',
#  'Jun\xc3\xadn',
#  'Jeppener',
# ...

# %%
eaw = ['ewa','elala','xd']
la = ['mmm','ewa']
eaw.extend(la)

# %%
eaw + la
# Out:
# ['ewa', 'elala', 'xd', 'mmm', 'ewa', 'mmm', 'ewa']

# %%
listaNombresCapFedYBsAs = listaCapFed + listaBsAsInterior + listaCostaAtl + listaZonaNorte + listaZonaOeste + listaZonaSur

# %%
listaNombresCapFedYBsAs
# Out:
# ['Palermo',
#  'Villa del Parque',
#  'Barracas',
#  'Congreso',
#  'Parque Patricios',
#  'Belgrano',
#  'Capital Federal',
#  'Flores',
#  'Villa Crespo',
#  'Parque Avellaneda',
#  'Villa Urquiza',
#  'San Cristobal',
#  'Boedo',
#  'Almagro',
#  'Saavedra',
#  'Puerto Madero',
#  'Barrio Norte',
#  'Villa Devoto',
#  'Coghlan',
#  'Balvanera',
#  'Caballito',
#  'Villa Real',
#  'Retiro',
#  'Boca',
#  'Abasto',
#  'Villa Lugano',
#  'Monte Castro',
#  'Monserrat',
#  'Mataderos',
#  'Once',
#  'Recoleta',
#  'Villa Santa Rita',
#  'Palermo Hollywood',
#  'Floresta',
#  'Nu\xc3\xb1ez',
#  'Paternal',
#  'Villa Luro',
#  'Liniers',
#  'Chacarita',
#  'Colegiales',
#  'Villa Pueyrred\xc3\xb3n',
#  'Las Ca\xc3\xb1itas',
#  'San Nicol\xc3\xa1s',
#  'Palermo Chico',
#  'Parque Chacabuco',
#  'Palermo Soho',
#  'Centro / Microcentro',
#  'Constituci\xc3\xb3n',
#  'Pompeya',
#  'San Telmo',
#  'Catalinas',
#  'Villa General Mitre',
#  'Agronom\xc3\xada',
#  'Versalles',
# ...

# %% [markdown]
# # Con las listas creadas anteriormente filtro

# %%
properati.shape
# Out:
# (2512307, 29)

# %%
properati2 = properati[properati.place_name.isin(listaNombresCapFedYBsAs)]
properati2
# Out:
#         country_name created_on currency  \
# 0                NaN 2012-08-08      NaN
# 1                NaN 2012-08-08      NaN
# 2                NaN 2012-08-08      NaN
# 3                NaN 2012-08-08      NaN
# 4                NaN 2012-08-08      USD
# 5                NaN 2012-08-08      NaN
# 6                NaN 2012-08-08      NaN
# 7                NaN 2012-08-08      USD
# 8                NaN 2012-08-08      NaN
# 9                NaN 2012-08-08      NaN
# 10               NaN 2012-08-08      NaN
# 11               NaN 2012-08-08      USD
# 12               NaN 2012-08-08      USD
# 13               NaN 2012-08-08      USD
# 14               NaN 2012-08-08      USD
# 15               NaN 2012-08-08      USD
# 16               NaN 2012-08-08      USD
# 17               NaN 2012-08-09      USD
# 18               NaN 2012-08-15      NaN
# 19               NaN 2012-08-15      USD
# 20               NaN 2012-08-15      USD
# 21               NaN 2012-08-17      USD
# ...

# %%
properati2.shape
# Out:
# (2252638, 29)

# %%
properati2.shape
# Out:
# (2252638, 29)

# %%
properati2.place_name.isnull().sum()
# Out:
# 143

# %%
import calendar

# %%
properati2['anio'] = properati2['created_on'].map(lambda x: x.year)
# Out:
# D:\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
properati2['anio']
# Out:
# 0          2012
# 1          2012
# 2          2012
# 3          2012
# 4          2012
# 5          2012
# 6          2012
# 7          2012
# 8          2012
# 9          2012
# 10         2012
# 11         2012
# 12         2012
# 13         2012
# 14         2012
# 15         2012
# 16         2012
# 17         2012
# 18         2012
# 19         2012
# 20         2012
# 21         2012
# 22         2012
# 23         2012
# 24         2012
# 25         2012
# 26         2012
# 27         2012
# 28         2012
# 29         2012
#            ...
# 2629121    2017
# 2629122    2017
# 2629123    2017
# 2629124    2017
# 2629125    2017
# 2629126    2017
# 2629127    2017
# 2629128    2017
# 2629129    2017
# 2629130    2017
# 2629131    2017
# 2629132    2017
# 2629133    2017
# 2629134    2017
# 2629135    2017
# 2629136    2017
# 2629137    2017
# 2629139    2017
# 2629141    2017
# 2629142    2017
# 2629143    2017
# 2629144    2017
# 2629145    2017
# 2629146    2017
# ...

# %%
properati2.loc[properati2['anio'] == 2017,:].groupby('property_type').count()
# Out:
#                country_name  created_on  currency  description  expenses  \
# property_type
# PH                    17308       17308     16515        17308       870
# apartment            165203      165203    155496       165199     27337
# house                 89101       89101     81519        89101      3817
# store                  8207        8207      7321         8207       612
#
#                extra  floor  geonames_id      id  image_thumbnail   ...    \
# property_type                                                       ...
# PH                 0    994        15081   17308            17187   ...
# apartment          0  27092       140733  165203           163044   ...
# house              0    309        64720   89101            87976   ...
# store              0    101         6944    8207             8014   ...
#
#                price_per_m2  price_usd_per_m2  properati_url   rooms  \
# property_type
# ...

# %%
properati.shape
# Out:
# (2512307, 29)

# %%
#properati[properati.place_name == "Luj\xc3\xa1n"]['place_name']

# %%
properati.place_name.value_counts(dropna=False)
# Out:
# Mar del Plata                      233110
# Capital Federal                     87511
# Tigre                               69852
# Pilar                               67584
# Nordelta                            61812
# Belgrano                            60378
# Ramos Mejía                         55799
# Palermo                             52837
# Punta del Este                      44823
# Rosario                             41816
# Córdoba                             40493
# La Plata                            39120
# Caballito                           38267
# Olivos                              35780
# Morón                               34400
# San Isidro                          32915
# Ituzaingó                           31348
# Pinamar                             30064
# Villa Urquiza                       29089
# Benavidez                           29039
# Flores                              28909
# Barrio Norte                        28375
# ...

# %%
properati.place_name.isnull().sum()
# Out:
# 143
